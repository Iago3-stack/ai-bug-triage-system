# %%
usuario = input("olá qual é o seu nome ?") 
idade = float(input(' qual a sua idade ?)
nascimento = int
# Out:
# olá qual é o seu nome ? iago nunes

# %%
print(usuario)
# Out:
# iago nunes

# %%
FAÇA UM PROGRAMA QUE PEÇA SUA IDADE SEU ANO DE NASCIMENTO E O MES EM QUE NASCEU E EXIBA O RESUILTADO NA TELA
